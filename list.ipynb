# %%
list1 = ['physics', 'chemistry', 1997, 2000];
list2 = [1, 2, 3, 4, 5, 6, 7 ];
print ("list1[0]: ", list1[2])
print ("list2[1:5]: ", list2[1:3])
# Out:
# list1[0]:  1997
# list2[1:5]:  [2, 3]

# %%
list = ['physics', 'chemistry', 1997, 2000];
print ("Value available at index 2 : ")
print (list[2])
list[2] = 999999;
print ("New value available at index 2 : ")
print (list[2])
# Out:
# Value available at index 2 :
# 1997
# New value available at index 2 :
# 999999

# %%
list1 = ['physics', 'chemistry', 1997, 2000];
print (list1)
del (list1[2]);
print ("After deleting value at index 2 :")
print (list1)
# Out:
# ['physics', 'chemistry', 1997, 2000]
# After deleting value at index 2 :
# ['physics', 'chemistry', 2000]

# %%
list1, list2 = [123, 'xyz', 'zara'], [456, 'abc']
print ("First list length : ", len(list1))
print ("Second list length : ", len(list2))
# Out:
# First list length :  3
# Second list length :  2

# %%
aList = [123, 'xyz', 'zara', 'abc'];
aList.append( 2009 );
print ("Updated List : ", aList)
# Out:
# Updated List :  [123, 'xyz', 'zara', 'abc', 2009]

# %%
aList = [123, 'xyz', 'xyz', 'abc', 123];
print ("Count for xyz : ", aList.count('xyz'))
print ("Count for zara : ", aList.count('zara'))
# Out:
# Count for xyz :  2
# Count for zara :  0

# %%
aList = [123, 'xyz', 'zara', 'abc', 123];
bList = [2009, 'brinda'];
aList.extend(bList)
print ("Extended List : ", aList)
# Out:
# Extended List :  [123, 'xyz', 'zara', 'abc', 123, 2009, 'brinda']

# %%
aList = [123, 'xyz', 'zara', 'abc', 'zara'];
print ("Index for xyz : ", aList.index( 'xyz' ) )
print ("Index for zara : ", aList.index( 'zara' ) )
# Out:
# Index for xyz :  1
# Index for zara :  2

# %%
aList = [123, 'xyz', 'zara', 'abc']
aList.insert( 3, 2009)
print ("Final List : ", aList)
# Out:
# Final List :  [123, 'xyz', 'zara', 2009, 'abc']

# %%
aList = [123, 'xyz', 'zara', 'abc'];

print(aList)

print ("List after popping last element : ", aList.pop())

print(aList)

print ("List after popping element from mentioned index: ", aList.pop(2))

print(aList)

aList.insert(3, 2009)

print(aList)
# Out:
# [123, 'xyz', 'zara', 'abc']
# List after popping last element :  abc
# [123, 'xyz', 'zara']
# List after popping element from mentioned index:  zara
# [123, 'xyz']
# [123, 'xyz', 2009]

# %%
aList = [123, 'xyz', 'zara', 'abc', 'xyz'];
aList.remove('xyz');
print ("List : ", aList)
aList.remove('abc');
print ("List : ", aList)
# Out:
# List :  [123, 'zara', 'abc', 'xyz']
# List :  [123, 'zara', 'xyz']

# %%
aList = ['shabnam', 'xyz', 'zara', 'abc', 'nive'];
aList.reverse();
print ("List : ", aList)
# Out:
# List :  ['nive', 'abc', 'zara', 'xyz', 'shabnam']

# %%
aList = ['abishek', 'brinda', 'ananya', 'arun', 'arjun'];
aList.sort();
print ("List : ", aList)
# Out:
# List :  ['abishek', 'ananya', 'arjun', 'arun', 'brinda']

# %%
aList = [123, 'xyz', 'zara', 'abc', 'xyz'];
aList.sort();
print ("List : ", aList)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-d16445a53ada> in <module>()
#       1 aList = [123, 'xyz', 'zara', 'abc', 'xyz'];
# ----> 2 aList.sort();
#       3 print ("List : ", aList)
#
# TypeError: '<' not supported between instances of 'str' and 'int'
